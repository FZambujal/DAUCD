# %%
import requests
import json

# %%
import pandas as pd

# %%
atractions = requests.get('https://failteireland.azure-api.net/opendata-api/v1/attractions')

# %%
print(atractions.json())
# Out:
# {'count': '1533', 'nextPage': 'https://failteireland.azure-api.net/opendata-api/v1/attractions?subscription-key=&search=*&$skip=50', 'results': [{'@context': 'http://schema.org', '@type': ['LocalBusiness', 'TouristAttraction', 'LandmarksOrHistoricalBuildings'], 'name': 'Donegal Castle', 'url': 'http://www.heritageireland.ie/en/north-west/donegalcastle/', 'geo': {'@type': 'GeoCoordinates', 'longitude': -8.11090678042603, 'latitude': 54.6544036482746}, 'telephone': '+353749722405', 'address': {'@type': 'PostalAddress', 'addressLocality': 'Donegal Town', 'addressRegion': 'Donegal', 'addressCountry': 'Republic of Ireland'}, 'image': {'@type': 'ImageObject', 'caption': 'Fáilte Ireland Logo', 'url': 'https://failtecdn.azureedge.net/failteireland/F%C3%A1ilte_Ireland_Logo_OpenDataAPI.jpg'}, 'tags': ['Activity', 'Attraction', 'Historic Houses and Castle', 'Castle']}, {'@context': 'http://schema.org', '@type': ['LocalBusiness', 'SportsActivityLocation', 'TouristAttraction', 'CafeOrCoffeeShop']
# ...

# %%
df = pd.DataFrame(atractions.json())
df.set_index('results').head()
# Out:
#                                                    count  \
# results
# {'@context': 'http://schema.org', '@type': ['Lo...  1533
# {'@context': 'http://schema.org', '@type': ['Lo...  1533
# {'@context': 'http://schema.org', '@type': ['Lo...  1533
# {'@context': 'http://schema.org', '@type': ['Lo...  1533
# {'@context': 'http://schema.org', '@type': ['Lo...  1533
#
#                                                                                              nextPage
# results
# {'@context': 'http://schema.org', '@type': ['Lo...  https://failteireland.azure-api.net/opendata-a...
# {'@context': 'http://schema.org', '@type': ['Lo...  https://failteireland.azure-api.net/opendata-a...
# {'@context': 'http://schema.org', '@type': ['Lo...  https://failteireland.azure-api.net/opendata-a...
# {'@context': 'http://schema.org', '@type': ['Lo...  https://failteireland.azure-api.net/opendata-a...
# ...

# %%
spotify = requests.get("https://api.spotify.com")

# %%
display(spotify)
# Out:
# <Response [200]>
