# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Importing both CSV files from Craft Beers Dataset
beers = pd.read_csv("beers.csv", index_col=0)
brew = pd.read_csv("breweries.csv", index_col=0)

#Adding a new column 
brew['brewery_id'] = brew.index

#Merging both dataframes
all_beers = beers.merge(brew, on="brewery_id")
all_beers.head()
# Out:
#      abv  ibu    id               name_x                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces                     name_y  city state
# 0         408    12.0  10 Barrel Brewing Company  Bend    OR
# 1         177    12.0        18th Street Brewery  Gary    IN
# 2         177    12.0        18th Street Brewery  Gary    IN
# 3         177    12.0        18th Street Brewery  Gary    IN
# 4         177    12.0        18th Street Brewery  Gary    IN

# %%
#Renaming columns to make data more readable

all_beers = all_beers.rename(index=str, columns={"name_x":"beer_name", "name_y":"brewery_name"})


# Make ABV a percentage for readability in the plots

all_beers['abv'] = all_beers['abv']*100
all_beers.head()
# Out:
#    abv  ibu    id            beer_name                           style  \
# 0  5.0  NaN  1436             Pub Beer             American Pale Lager
# 1  6.6  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  7.1  NaN  2264  Rise of the Phoenix                    American IPA
# 3  9.0  NaN  2263             Sinister  American Double / Imperial IPA
# 4  7.5  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces               brewery_name  city state
# 0         408    12.0  10 Barrel Brewing Company  Bend    OR
# 1         177    12.0        18th Street Brewery  Gary    IN
# 2         177    12.0        18th Street Brewery  Gary    IN
# 3         177    12.0        18th Street Brewery  Gary    IN
# 4         177    12.0        18th Street Brewery  Gary    IN

# %%
all_beers.info
# Out:
# <bound method DataFrame.info of       abv   ibu    id             beer_name                           style  \
# 0     5.0   NaN  1436              Pub Beer             American Pale Lager
# 1     6.6   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     7.1   NaN  2264   Rise of the Phoenix                    American IPA
# 3     9.0   NaN  2263              Sinister  American Double / Imperial IPA
# 4     7.5   NaN  2262         Sex and Candy                    American IPA
# ...   ...   ...   ...                   ...                             ...
# 2405  6.7  45.0   928             Belgorado                     Belgian IPA
# 2406  5.2   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  5.5   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  5.5  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  5.2   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces               brewery_name    city state
# 0            408    12.0  10 Barrel Brewing Company    Bend    OR
# 1            177    12.0        18th Street Brewery    Gary    IN
# 2            177    12.0        18th Street Brewery    Gary    IN
# 3            177    12.0        18th Street Brewery    Gary    IN
# 4            177    12.0        18th Street Brewery    Gary    IN
# ...          ...     ...                        ...     ...   ...
# 2405         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2406         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2407         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2408         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2409         424    12.0    Wynkoop Brewing Company  Denver    CO
#
# [2410 rows x 10 columns]>

# %%
#data cleaning
all_beers.isna().sum()
# Out:
# abv               62
# ibu             1005
# id                 0
# beer_name          0
# style              5
# brewery_id         0
# ounces             0
# brewery_name       0
# city               0
# state              0
# dtype: int64

# %%
#Dropping "ibu" columns since the amount of missing values represent 40% of the total results
all_beers.drop(columns=["ibu"])
# Out:
#       abv    id             beer_name                           style  \
# 0     5.0  1436              Pub Beer             American Pale Lager
# 1     6.6  2265           Devil's Cup         American Pale Ale (APA)
# 2     7.1  2264   Rise of the Phoenix                    American IPA
# 3     9.0  2263              Sinister  American Double / Imperial IPA
# 4     7.5  2262         Sex and Candy                    American IPA
# ...   ...   ...                   ...                             ...
# 2405  6.7   928             Belgorado                     Belgian IPA
# 2406  5.2   807         Rail Yard Ale        American Amber / Red Ale
# 2407  5.5   620       B3K Black Lager                     Schwarzbier
# 2408  5.5   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  5.2    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces               brewery_name    city state
# 0            408    12.0  10 Barrel Brewing Company    Bend    OR
# 1            177    12.0        18th Street Brewery    Gary    IN
# 2            177    12.0        18th Street Brewery    Gary    IN
# 3            177    12.0        18th Street Brewery    Gary    IN
# 4            177    12.0        18th Street Brewery    Gary    IN
# ...          ...     ...                        ...     ...   ...
# 2405         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2406         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2407         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2408         424    12.0    Wynkoop Brewing Company  Denver    CO
# 2409         424    12.0    Wynkoop Brewing Company  Denver    CO
#
# [2410 rows x 9 columns]

# %%
#fill empty cells for abv
all_beers["abv"].fillna( method ='ffill', inplace = True)

# %%
all_beers.isna().sum()
# Out:
# abv                0
# ibu             1005
# id                 0
# beer_name          0
# style              5
# brewery_id         0
# ounces             0
# brewery_name       0
# city               0
# state              0
# dtype: int64

# %%
all_beers[all_beers['style']== 'Null']
# Out:
# Empty DataFrame
# Columns: [abv, ibu, id, beer_name, style, brewery_id, ounces, brewery_name, city, state]
# Index: []

# %%
brew = pd.read_csv("breweries.csv", index_col=0)

# %%
brew.head()
# Out:
#                         name           city state
# 0         NorthGate Brewing     Minneapolis    MN
# 1  Against the Grain Brewery     Louisville    KY
# 2   Jack's Abby Craft Lagers     Framingham    MA
# 3  Mike Hess Brewing Company      San Diego    CA
# 4    Fort Point Beer Company  San Francisco    CA

# %%
brew.isna().sum()
# Out:
# name     0
# city     0
# state    0
# dtype: int64

# %%
brew.info
# Out:
# <bound method DataFrame.info of                               name           city state
# 0               NorthGate Brewing     Minneapolis    MN
# 1        Against the Grain Brewery     Louisville    KY
# 2         Jack's Abby Craft Lagers     Framingham    MA
# 3        Mike Hess Brewing Company      San Diego    CA
# 4          Fort Point Beer Company  San Francisco    CA
# ..                             ...            ...   ...
# 553            Covington Brewhouse      Covington    LA
# 554                Dave's Brewfarm         Wilson    WI
# 555          Ukiah Brewing Company          Ukiah    CA
# 556        Butternuts Beer and Ale  Garrattsville    NY
# 557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 3 columns]>

# %%
brewery = brew.rename(columns={"name": "brewery", "city": "brewery city", "state":"brewery state"})

# %%
#Merge Tables
brewery.index.name = 'brewery_id'
all_beers = beers_clean.merge(brewery, on="brewery_id", how="left")
all_beers
# Out:
#         abv    id                  name                           style  \
# 0     0.050  1436              Pub Beer             American Pale Lager
# 1     0.066  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071  2264   Rise of the Phoenix                    American IPA
# 3     0.090  2263              Sinister  American Double / Imperial IPA
# 4     0.075  2262         Sex and Candy                    American IPA
# ...     ...   ...                   ...                             ...
# 2405  0.067   928             Belgorado                     Belgian IPA
# 2406  0.052   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   620       B3K Black Lager                     Schwarzbier
# 2408  0.055   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces                    brewery brewery city brewery state
# 0            408    12.0  10 Barrel Brewing Company         Bend            OR
# 1            177    12.0        18th Street Brewery         Gary            IN
# 2            177    12.0        18th Street Brewery         Gary            IN
# 3            177    12.0        18th Street Brewery         Gary            IN
# 4            177    12.0        18th Street Brewery         Gary            IN
# ...          ...     ...                        ...          ...           ...
# 2405         424    12.0    Wynkoop Brewing Company       Denver            CO
# 2406         424    12.0    Wynkoop Brewing Company       Denver            CO
# 2407         424    12.0    Wynkoop Brewing Company       Denver            CO
# 2408         424    12.0    Wynkoop Brewing Company       Denver            CO
# 2409         424    12.0    Wynkoop Brewing Company       Denver            CO
#
# [2410 rows x 9 columns]

# %%
all_beers.groupby('brewery')
all_beers
# Out:
#         abv    id                           style  brewery_id  ounces  \
# 0     0.050  1436             American Pale Lager         408    12.0
# 1     0.066  2265         American Pale Ale (APA)         177    12.0
# 2     0.071  2264                    American IPA         177    12.0
# 3     0.090  2263  American Double / Imperial IPA         177    12.0
# 4     0.075  2262                    American IPA         177    12.0
# ...     ...   ...                             ...         ...     ...
# 2405  0.067   928                     Belgian IPA         424    12.0
# 2406  0.052   807        American Amber / Red Ale         424    12.0
# 2407  0.055   620                     Schwarzbier         424    12.0
# 2408  0.055   145         American Pale Ale (APA)         424    12.0
# 2409  0.052    84        American Amber / Red Ale         424    12.0
#
#                         brewery brewery city brewery state
# 0     10 Barrel Brewing Company         Bend            OR
# 1           18th Street Brewery         Gary            IN
# 2           18th Street Brewery         Gary            IN
# 3           18th Street Brewery         Gary            IN
# 4           18th Street Brewery         Gary            IN
# ...                         ...          ...           ...
# 2405    Wynkoop Brewing Company       Denver            CO
# 2406    Wynkoop Brewing Company       Denver            CO
# 2407    Wynkoop Brewing Company       Denver            CO
# 2408    Wynkoop Brewing Company       Denver            CO
# 2409    Wynkoop Brewing Company       Denver            CO
#
# [2410 rows x 8 columns]

# %%
gr = all_beers.groupby(["brewery", "style"])["name"].count()
gr
# Out:
# brewery                    style
# 10 Barrel Brewing Company  American Pale Lager               1
# 18th Street Brewery        American Double / Imperial IPA    2
#                            American IPA                      2
#                            American Pale Ale (APA)           4
#                            American Porter                   1
#                                                             ..
# Wynkoop Brewing Company    American Strong Ale               1
#                            Belgian IPA                       1
#                            Chile Beer                        1
#                            Pumpkin Ale                       1
#                            Schwarzbier                       1
# Name: name, Length: 1903, dtype: int64

# %%
styles = all_beers["style"].value_counts()

# %%
top_styles = styles[styles > 20]

plt.figure(figsize=(10,6))
plt.title('No. different beer styles')
g=sns.barplot(top_styles.index, top_styles, palette='Set2')
g.bar_label(g.containers[0], fmt='%.0f', fontsize=16)
plt.xticks(rotation=90)
plt.yticks([])
plt.ylabel('No. Beers')
plt.show()
# Out:
# /Users/filipa_zambujal/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Converting DataFrames to NumPy Arrays

beers_array = beers.to_numpy()
beers_array
# Out:
# array([[0.05, nan, 1436, ..., 'American Pale Lager', 408, 12.0],
#        [0.066, nan, 2265, ..., 'American Pale Ale (APA)', 177, 12.0],
#        [0.071, nan, 2264, ..., 'American IPA', 177, 12.0],
#        ...,
#        [0.055, nan, 620, ..., 'Schwarzbier', 424, 12.0],
#        [0.055, 40.0, 145, ..., 'American Pale Ale (APA)', 424, 12.0],
#        [0.052, nan, 84, ..., 'American Amber / Red Ale', 424, 12.0]],
#       dtype=object)

# %%
brew_array = brew.to_numpy()
brew_array
# Out:
# array([['NorthGate Brewing ', 'Minneapolis', ' MN'],
#        ['Against the Grain Brewery', 'Louisville', ' KY'],
#        ["Jack's Abby Craft Lagers", 'Framingham', ' MA'],
#        ...,
#        ['Ukiah Brewing Company', 'Ukiah', ' CA'],
#        ['Butternuts Beer and Ale', 'Garrattsville', ' NY'],
#        ['Sleeping Lady Brewing Company', 'Anchorage', ' AK']],
#       dtype=object)
